# %%
# libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.io as pio

# Load script.
df = pd.read_csv('~/project_git/operational-graph-intelligence/customer_support_simulated.csv')
df1 = pd.read_csv('~/project_git/operational-graph-intelligence/staffing_sweep_raw.csv')
df2 = pd.read_csv('~/project_git/operational-graph-intelligence/staffing_sweep_summary.csv')

# in classic Jupyter Notebook:
pio.renderers.default = "notebook"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       5 import plotly.graph_objects as go
#       6 import plotly.io as pio
#       7
#       8 # Load script.
# ----> 9 df = pd.read_csv('~/project_git/operational-graph-intelligence/customer_support_simulated.csv')
#      10 df1 = pd.read_csv('~/project_git/operational-graph-intelligence/staffing_sweep_raw.csv')
#      11 df2 = pd.read_csv('~/project_git/operational-graph-intelligence/staffing_sweep_summary.csv')
#      12
#
# ...

# %% [markdown]
# # Eagle View

# %%
df.head(3)

# %%
df.dtypes

# %%
df.count(axis=0)

# %% [markdown]
# ## Plotly graph to visualize data.

# %% [markdown]
# ### Plotly 'Case_type' visualization

# %%
# Counts for the categorical data.
## Case type
counts_case_type = df['case_type'].value_counts().sort_index()
cats_case_type = counts_case_type.index.tolist()
vals_case_type = counts_case_type.values.tolist()
## Case type
counts_region = df['region'].value_counts().sort_index()
cats_region = counts_region.index.tolist()
vals_region = counts_region.values.tolist()

# %%
fig = go.Figure()

# one trace per category (visible toggled by dropdown)
for i, c in enumerate(cats_case_type):
    fig.add_trace(go.Bar(x=[c], y=[vals_case_type[i]], name=c, visible=False))

# add "All" trace (aggregate)
fig.add_trace(go.Bar(x=cats_case_type, y=vals_case_type, name='All', visible=True))

# dropdown buttons
buttons = [
    dict(label='All',
         method='update',
         args=[{'visible': [False]*len(cats_case_type) + [True]},
               {'title': 'All categories'}]),
]
# one button per category
for i, c in enumerate(cats_case_type):
    vis = [False]*len(cats_case_type) + [False]
    vis[i] = True
    buttons.append(dict(label=c,
                        method='update',
                        args=[{'visible': vis},
                              {'title': f'Category: {c}'}]))

fig.update_layout(
    updatemenus=[dict(active=0, buttons=buttons, x=0.0, y=1.15)],
    title='Counts by case_type',
    xaxis_title='case_type',
    yaxis_title='count'
)
fig.show()

# %%
fig = go.Figure()

# one trace per category (visible toggled by dropdown)
for i, c in enumerate(cats_region):
    fig.add_trace(go.Bar(x=[c], y=[vals_region[i]], name=c, visible=False))

# add "All" trace (aggregate)
fig.add_trace(go.Bar(x=cats_region, y=vals_region, name='All', visible=True))

# dropdown buttons
buttons = [
    dict(label='All',
         method='update',
         args=[{'visible': [False]*len(cats_region) + [True]},
               {'title': 'All categories'}]),
]
# one button per category
for i, c in enumerate(cats_region):
    vis = [False]*len(cats_region) + [False]
    vis[i] = True
    buttons.append(dict(label=c,
                        method='update',
                        args=[{'visible': vis},
                              {'title': f'Category: {c}'}]))

fig.update_layout(
    updatemenus=[dict(active=0, buttons=buttons, x=0.0, y=1.15)],
    title='Counts by case_type',
    xaxis_title='case_type',
    yaxis_title='count'
)
fig.show()
